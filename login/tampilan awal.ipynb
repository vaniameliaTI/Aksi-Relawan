# %%
# %%html
# <!DOCTYPE html>
# <html lang="id">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title>Volunteer Website</title>
#     <script src="https://cdn.tailwindcss.com"></script>
# </head>
# <body class="bg-gray-100">
#
#     <!-- Navbar -->
#     <nav class="bg-[#8B4513] text-white p-4">
#         <div class="container mx-auto flex justify-between items-center">
#             <h1 class="text-xl font-bold">Aksi Relawan</h1>
#             <ul class="hidden md:flex space-x-6">
#                 <li><a href="#" class="hover:underline">Beranda</a></li>
#                 <li><a href="#" class="hover:underline">Cari Aktivitas</a></li>
#                 <li><a href="#" class="hover:underline">Hubungi Kami</a></li>
#                 <li><a href="#" class="hover:underline">Tentang Kami</a></li>
#             </ul>
#             <div class="space-x-4">
#                 <a href="login.html" class="bg-white text-black px-4 py-2 rounded-lg border border-green-600 hover:bg-gray-200">Masuk</a>
#                 <a href="signin.html" class="bg-green-600 text-white px-4 py-2 rounded-lg hover:bg-green-700">Daftar</a>
#             </div>
#         </div>
#     </nav>
#
#     <!-- Hero Section -->
#     <header class="relative h-[500px] bg-cover bg-center flex items-center justify-center" style="background-image: url('https://source.unsplash.com/1600x900/?volunteer,community');">
#         <div class="absolute inset-0 bg-black opacity-40"></div>
#         <div class="text-center text-white relative z-10 px-6">
#             <h1 class="text-4xl font-bold">Mulai Aksi Kebaikanmu Sekarang!</h1>
#             <p class="text-lg mt-2">"Saatnya Bertindak!"<br> Jangan cuma peduli, tunjukkan aksi nyata dengan menjadi bagian dari perubahan!</p>
#
#             <!-- Search Form -->
#             <div class="mt-6 flex justify-center space-x-2">
#                 <select class="p-2 border rounded-lg text-black">
#                     <option>Peran atau Organisasi</option>
#                 </select>
#                 <select class="p-2 border rounded-lg text-black">
#                     <option>Pilih Lokasi</option>
#                 </select>
#                 <select class="p-2 border rounded-lg text-black">
#                     <option>Pilih Kategori</option>
#                 </select>
#                 <button class="bg-[#8B4513] text-white px-4 py-2 rounded-lg hover:bg-[#6a3210]">Cari</button>
#             </div>
#         </div>
#     </header>
#
# </body>
# </html>
# Out:
# <!DOCTYPE html>
# <html lang="id">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title>Volunteer Website</title>
#     <script src="https://cdn.tailwindcss.com"></script>
# </head>
# <body class="bg-gray-100">
#
#     <!-- Navbar -->
#     <nav class="bg-[#8B4513] text-white p-4">
#         <div class="container mx-auto flex justify-between items-center">
#             <h1 class="text-xl font-bold">Aksi Relawan</h1>
#             <ul class="hidden md:flex space-x-6">
#                 <li><a href="#" class="hover:underline">Beranda</a></li>
#                 <li><a href="#" class="hover:underline">Cari Aktivitas</a></li>
#                 <li><a href="#" class="hover:underline">Hubungi Kami</a></li>
#                 <li><a href="#" class="hover:underline">Tentang Kami</a></li>
#             </ul>
#             <div class="space-x-4">
# ...
